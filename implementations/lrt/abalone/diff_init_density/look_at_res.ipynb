# %%
import numpy as np
import matplotlib.pyplot as plt
alpha_levels = np.array(["0.001-0.01","0.01-0.1","0.1-0.25","0.25-0.5","0.5-0.75","0.75-0.9","0.9-0.99","0.99-0.999"])
median_res_abalone_lrt = np.array(
    [
        [  2.14488482,  17., 0.59084809],
        [  2.11656117,  22., 0.60158259],
        [  2.11164379,  27., 0.6034317 ],
        [  2.11894608,  20., 0.60068429],
        [  2.11989951,  54., 0.60032481],
        [  2.06793904,  46., 0.61967748],
        [  2.04771638, 114., 0.62707949],
        [  2.03977776, 159., 0.62996542]
    ]
)

median_res_abalone_lrt[:,-1] = median_res_abalone_lrt[:,-1]**0.5

names = ["RMSE", "Nr. of used weights in MPM", "Correlation"]

for i in range(3):
    fig, ax = plt.subplots()
    x_values = np.arange(len(alpha_levels))
    ax.plot(x_values, median_res_abalone_lrt[:,i],"-o")
    
    # Set the x-tick locations (optional, if you want specific positions)
    ax.set_xticks(x_values) 
    ax.set_ylabel(names[i])
    ax.set_xlabel("Inital alpha value range")
    # Set the new labels for the x-ticks
    ax.set_xticklabels(alpha_levels, rotation=60)
    plt.grid()
    plt.title("Median probability model")
    plt.tight_layout()
    plt.savefig(f"results/mpm/{names[i]}.png")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
alpha_levels = np.array(["0.001-0.01","0.01-0.1","0.1-0.25","0.25-0.5","0.5-0.75","0.75-0.9","0.9-0.99","0.99-0.999"])
median_res_abalone_lrt = np.array(
[[2.1443825e+00, 3.8804812e-04, 5.9103978e-01],
 [2.1169543e+00, 5.0217990e-04, 6.0143459e-01],
 [2.1101706e+00, 6.1631174e-04, 6.0398489e-01],
 [2.1186385e+00, 4.5652720e-04, 6.0080016e-01],
 [2.1202919e+00, 1.2326235e-03, 6.0017681e-01],
 [2.0670333e+00, 1.0500125e-03, 6.2001050e-01],
 [2.0482650e+00, 2.6022049e-03, 6.2687969e-01],
 [2.0374932e+00, 3.6293913e-03, 6.3079381e-01]])

median_res_abalone_lrt[:,-1] = median_res_abalone_lrt[:,-1]**0.5

names = ["RMSE", "Nr. of used weights in MPM", "Correlation"]

for i in range(3):
    fig, ax = plt.subplots()
    x_values = np.arange(len(alpha_levels))
    ax.plot(x_values, median_res_abalone_lrt[:,i],"-o")
    
    # Set the x-tick locations (optional, if you want specific positions)
    ax.set_xticks(x_values) 
    ax.set_ylabel(names[i])
    ax.set_xlabel("Inital alpha value range")
    # Set the new labels for the x-ticks
    ax.set_xticklabels(alpha_levels, rotation=60)
    plt.grid()
    plt.title("Full model")
    plt.tight_layout()
    plt.savefig(f"results/full/{names[i]}.png")
    plt.show()
