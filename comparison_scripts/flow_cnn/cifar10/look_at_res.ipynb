# %%
import pandas as pd
import numpy as np

flow_res = pd.read_csv("results/flow_networks_cifar10_results.csv")

cols = ["accuracy_full", "accuracy_median", "loss_full", "loss_median", "ece_full", "ece_median"]

for col in cols:
    c = flow_res[col]
    print(f"{col}:\n{np.median(c):.3f} ({np.min(c):.3f}, {np.max(c):.3f})\n")
# Out:
# accuracy_full:
# 47.820 (47.480, 48.340)
#
# accuracy_median:
# 47.230 (46.620, 47.580)
#
# loss_full:
# 25156.000 (25060.545, 25291.438)
#
# loss_median:
# 25233.468 (25147.285, 25462.527)
#
# ece_full:
# 0.011 (0.007, 0.015)
#
# ece_median:
# 0.012 (0.009, 0.024)

# %%
flow_res
# Out:
#    network   loss_median     loss_full  accuracy_median  accuracy_full  \
# 0        0  25371.464844  25210.634766            46.79          47.91
# 1        1  25147.285156  25061.597656            47.55          48.02
# 2        2  25462.527344  25291.437500            46.62          47.48
# 3        3  25231.609375  25205.537109            47.33          47.85
# 4        4  25365.904297  25253.017578            47.10          47.70
# 5        5  25164.339844  25060.544922            47.29          47.79
# 6        6  25253.246094  25139.328125            47.28          47.57
# 7        7  25222.185547  25093.001953            47.18          48.34
# 8        8  25235.326172  25110.722656            47.58          48.07
# 9        9  25227.406250  25172.671875            47.02          47.64
#
#    ece_median  ece_full  nr_active_weights
# 0    0.022416  0.014677               1057
# 1    0.011982  0.011393               1079
# 2    0.011060  0.007673               1090
# 3    0.009062  0.010434               1067
# 4    0.012304  0.008853               1062
# 5    0.012835  0.011163               1003
# 6    0.023756  0.012254                989
# 7    0.011441  0.007023                925
# 8    0.009774  0.014471               1032
# 9    0.016492  0.013325               1061
